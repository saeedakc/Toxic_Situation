# %%
import random 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create Pathway of Summary files
WC_Data = "output_data/WC_Litter.csv"
EC_Data = "output_data/EC_Litter.csv"

# Read all the summary files
WC_pd = pd.read_csv(WC_Data)
EC_pd = pd.read_csv(EC_Data)

# %%
WC_pd
# Out:
#              State  Plastic Waste  Foam Waste  Fisherman's Waste  \
# 0      Alaska, USA          17089       17001               4451
# 1  California, USA        1513814      439899              45287
# 2      Hawaii, USA         162594       27640              22564
# 3      Oregon, USA         109147       23946               4098
# 4  Washington, USA          98557       40371              10013
#
#    Smoking Waste Items  Misc Food Waste Items  Miscellaneous Waste Items
# 0                11356                  10504                    13506.0
# 1               838130                 646930                   463359.0
# 2                92206                  44719                    46293.0
# 3                29913                  18316                    14395.0
# 4                67107                  40412                    41235.0

# %%
# Create values for Pie Chart
wc_waste_cat = ["Plastic Waste", "Foam Waste", "Fisherman's Waste", 
            "Smoking Waste Items", "Misc Food Waste Items", 
             "Miscellaneous Waste Items"]
wc_total_per_cat = [1901201, 548857, 86413, 1038712, 760881, 578788]
wc_colors = ["red", "orange", "pink", "violet", "yellow", "green"]
wc_explode = [0.1,0,0,0,0,0]

# Create pie chart based on our values above
plt.pie(wc_total_per_cat, explode=wc_explode, labels=wc_waste_cat, colors=wc_colors,
       autopct="%1.1f%%", shadow=True)
plt.title("West Coast Pollutants")
# Out:
# Text(0.5, 1.0, 'West Coast Pollutants')

# %%
plt.savefig("output_data/West_Coast_Pollutants_Chart.png")

# %%
EC_pd
# Out:
#                   State  Plastic Waste  Foam Waste  Fisherman's Waste  \
# 0          Alabama, USA         162118       52720               8663
# 1      Connecticut, USA         121210     1076366               7306
# 2         Delaware, USA         104780       17237               6183
# 3          Florida, USA        2136662      326441              91921
# 4          Georgia, USA         117665       29566              10242
# 5        Louisiana, USA          99923       17611               5127
# 6            Maine, USA          59493       24553              15405
# 7         Maryland, USA         137983       89443               5934
# 8    Massachusetts, USA         194662     1734445              22658
# 9      Mississippi, USA         272746       96520              15740
# 10   New Hampshire, USA          30565      124788               8664
# 11      New Jersey, USA         247981       40086               8032
# 12        New York, USA         531150      137787              25011
# 13  North Carolina, USA         134397       34006               6057
# 14    Rhode Island, USA         212945       55080              21238
# 15  South Carolina, USA         123444       44163               9071
# 16           Texas, USA         568165      111735              44542
# 17        Virginia, USA         261140       71165               7226
#
#     Smoking Waste Items  Misc Food Waste Items  Miscellaneous Waste Items
# 0                102815                  83611                    32891.0
# 1                 82811                  58946                    22207.0
# 2                 58002                  36072                    16253.0
# 3                866500                 516453                   437590.0
# 4                107308                  47645                    67750.0
# 5                 19305                  29219                    19014.0
# 6                 98015                  24849                    20562.0
# 7                 30097                  30319                    16551.0
# 8                112408                  78640                    45557.0
# 9                162647                 117390                    65066.0
# 10                64128                  12026                     9188.0
# 11                69884                  89245                    39655.0
# 12               212475                 212727                   136847.0
# 13               137720                  66539                    42385.0
# 14               166780                  94181                    71354.0
# 15                98693                  47983                    37967.0
# 16               196452                 140885                   101938.0
# 17               114577                 119174                    63518.0

# %%
# Create values for Pie Chart
ec_waste_cat = ["Plastic Waste", "Foam Waste", "Fisherman's Waste", 
            "Smoking Waste Items", "Misc Food Waste Items", 
             "Miscellaneous Waste Items"]
ec_total_per_cat = [5517029, 4083712, 319020, 2700617, 1805904, 1246293]
ec_colors = ["blue", "grey", "maroon", "lightpink", "silver", "gold"]
ec_explode = [0.1,0,0,0,0,0]

# Create pie chart based on our values above
plt.pie(ec_total_per_cat, explode=ec_explode, labels=ec_waste_cat, colors=ec_colors,
       autopct="%1.1f%%", shadow=True)
plt.title("East Coast Pollutants")
# Out:
# Text(0.5, 1.0, 'East Coast Pollutants')

# %%
plt.savefig("output_data/East_Coast_Pollutants_Chart.png")
