# %%
# Dependencies

import numpy as np
import pandas as pd
import datetime

# %%
# Read CSV

supp_int_al = pd.read_csv("Resources/epa_ecoast/AL_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ct = pd.read_csv("Resources/epa_ecoast/CT_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_de = pd.read_csv("Resources/epa_ecoast/DE_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ga = pd.read_csv("Resources/epa_ecoast/GA_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_la = pd.read_csv("Resources/epa_ecoast/LA_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ma = pd.read_csv("Resources/epa_ecoast/MA_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_md = pd.read_csv("Resources/epa_ecoast/MD_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_me = pd.read_csv("Resources/epa_ecoast/ME_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ms = pd.read_csv("Resources/epa_ecoast/MS_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_nc = pd.read_csv("Resources/epa_ecoast/NC_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_nh = pd.read_csv("Resources/epa_ecoast/NH_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_nj = pd.read_csv("Resources/epa_ecoast/NJ_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ny = pd.read_csv("Resources/epa_ecoast/NY_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_ri = pd.read_csv("Resources/epa_ecoast/RI_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_sc = pd.read_csv("Resources/epa_ecoast/SC_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_tx = pd.read_csv("Resources/epa_ecoast/TX_SUPP_INTEREST_FILE.csv", low_memory=False)
supp_int_va = pd.read_csv("Resources/epa_ecoast/VA_SUPP_INTEREST_FILE.csv", low_memory=False)

# %%
# Add Column with State Abbrv

supp_int_al.insert(0,"state","al")
supp_int_ct.insert(0,"state","ct")
supp_int_de.insert(0,"state","de")
supp_int_ga.insert(0,"state","ga")
supp_int_la.insert(0,"state","la")
supp_int_ma.insert(0,"state","ma")
supp_int_md.insert(0,"state","md")
supp_int_me.insert(0,"state","me")
supp_int_ms.insert(0,"state","ms")
supp_int_nc.insert(0,"state","nc")
supp_int_nh.insert(0,"state","nh")
supp_int_nj.insert(0,"state","nj")
supp_int_ny.insert(0,"state","ny")
supp_int_ri.insert(0,"state","ri")
supp_int_sc.insert(0,"state","sc")
supp_int_tx.insert(0,"state","tx")
supp_int_va.insert(0,"state","va")

supp_int_va.head()
# Out:
#   state   REGISTRY_ID PGM_SYS_ACRNM    PGM_SYS_ID  \
# 0    va  110000339090          CEDS  200000075349
# 1    va  110000339090          ICIS         45531
# 2    va  110000339107          ICIS    2200000130
# 3    va  110000339107           RMP  100000051882
# 4    va  110000339107         NPDES     VA0004031
#
#                      INTEREST_TYPE SUP_PGM_SYS_ACRNM SUP_PGM_SYS_ID  \
# 0                     STATE MASTER              CEDS          40210
# 1        FORMAL ENFORCEMENT ACTION              ICIS   03-1996-0366
# 2  ENFORCEMENT/COMPLIANCE ACTIVITY              ICIS   03-2012-0152
# 3                     RMP REPORTER              ICIS            NaN
# 4             ICIS-NPDES NON-MAJOR              ICIS            NaN
#
#                  SUP_INTEREST_TYPE            START_DATE  \
# 0                      AIR PROGRAM                   NaN
# 1        FORMAL ENFORCEMENT ACTION  02-DEC-1997 00:00:00
# 2        FORMAL ENFORCEMENT ACTION  01-JUN-2012 00:00:00
# 3  ENFORCEMENT/COMPLIANCE ACTIVITY  19-JUN-2013 00:00:00
# 4  ENFORCEMENT/COMPLIANCE ACTIVITY  30-MAR-1982 00:00:00
#
#        START_DATE_QUALIFIER  END_DATE  END_DATE_QUALIFIER SOURCE_OF_DATA  \
# 0                       NaN       NaN                 NaN           CEDS
# 1  COMPLAINT/PROPOSED ORDER       NaN                 NaN           ICIS
# 2  COMPLAINT/PROPOSED ORDER       NaN                 NaN           ICIS
# 3      ACTUAL ACTIVITY DATE       NaN                 NaN           ICIS
# 4      ACTUAL ACTIVITY DATE       NaN                 NaN           ICIS
#
#      LAST_REPORTED_DATE       REPORTED_SUP_INTEREST_TYPE  \
# 0                   NaN                      AIR PROGRAM
# 1  08-AUG-2001 09:08:52        FORMAL ENFORCEMENT ACTION
# 2  14-JUN-2012 14:39:21        FORMAL ENFORCEMENT ACTION
# 3  22-JUL-2013 13:10:22  ENFORCEMENT/COMPLIANCE ACTIVITY
# 4  23-JUN-2014 10:22:30  ENFORCEMENT/COMPLIANCE ACTIVITY
#
#             CREATE_DATE           UPDATE_DATE
# 0  16-FEB-2005 11:37:56                   NaN
# 1  24-FEB-2007 14:12:40                   NaN
# 2  01-AUG-2012 12:21:10                   NaN
# 3  05-AUG-2013 10:44:34                   NaN
# 4  18-JAN-2016 00:00:00  06-FEB-2016 08:07:07

# %%
# Append files for complete East Coast

ent_supp_int = supp_int_al

ent_supp_int = ent_supp_int.append(supp_int_ct, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_de, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_ga, sort = True) 
ent_supp_int = ent_supp_int.append(supp_int_la, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_ma, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_md, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_me, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_ms, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_nc, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_nh, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_nj, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_ny, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_ri, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_sc, sort = True)
ent_supp_int = ent_supp_int.append(supp_int_va, sort = True)

# %%
# Value Count by State
pre_st_cnt = ent_supp_int["state"].value_counts()
pre_st_cnt
# Out:
# nj    583769
# ny    330724
# ga    151266
# ms    100353
# sc     73006
# nc     69009
# al     64648
# ma     64554
# la     44770
# ri     44182
# md     44069
# ct     29961
# de     26351
# va     15068
# me     10648
# nh      6587
# Name: state, dtype: int64

# %%
# Create DF for relevant values

relevant_df1 = pd.DataFrame({"State":ent_supp_int["state"],
                           "Main Interest Type":ent_supp_int["INTEREST_TYPE"], 
                           "Supplemental Interest Type":ent_supp_int["SUP_INTEREST_TYPE"],
                           "Start of Relief":ent_supp_int["START_DATE"],
                           "Create_dt of Relief":ent_supp_int["CREATE_DATE"]})
relevant_df1
# Out:
#       State               Main Interest Type       Supplemental Interest Type  \
# 0        al  ENFORCEMENT/COMPLIANCE ACTIVITY        FORMAL ENFORCEMENT ACTION
# 1        al                     STATE MASTER          NPDES STORMWATER PERMIT
# 2        al        FORMAL ENFORCEMENT ACTION        FORMAL ENFORCEMENT ACTION
# 3        al             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 4        al                     STATE MASTER          HAZARDOUS WASTE PROGRAM
# ...     ...                              ...                              ...
# 15063    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15064    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15065    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15066    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15067    va        FORMAL ENFORCEMENT ACTION        FORMAL ENFORCEMENT ACTION
#
#             Start of Relief   Create_dt of Relief
# 0      21-AUG-2002 00:00:00  24-FEB-2007 14:12:05
# 1                       NaN  22-JAN-2013 09:38:35
# 2      21-AUG-2002 00:00:00  24-FEB-2007 14:12:05
# 3      16-SEP-1988 00:00:00  04-MAR-2011 00:00:00
# 4                       NaN  22-JAN-2013 12:28:00
# ...                     ...                   ...
# 15063                   NaN  11-SEP-2019 06:28:44
# 15064                   NaN  11-SEP-2019 06:28:46
# 15065                   NaN  11-SEP-2019 06:28:19
# 15066                   NaN  11-SEP-2019 06:28:19
# 15067  17-DEC-2019 00:00:00  06-JAN-2020 10:49:53
#
# [1658965 rows x 5 columns]

# %%
# Remove non-water categories

relevant_df_Water = relevant_df1[~relevant_df1['Main Interest Type'].str.contains('AIR', na=False)]
relevant_df_Water = relevant_df1[~relevant_df1['Supplemental Interest Type'].str.contains('AIR|REMEDIATION|FUNDING', na=False)]
relevant_df_Water.head()
# Out:
#   State               Main Interest Type       Supplemental Interest Type  \
# 0    al  ENFORCEMENT/COMPLIANCE ACTIVITY        FORMAL ENFORCEMENT ACTION
# 1    al                     STATE MASTER          NPDES STORMWATER PERMIT
# 2    al        FORMAL ENFORCEMENT ACTION        FORMAL ENFORCEMENT ACTION
# 3    al             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 4    al                     STATE MASTER          HAZARDOUS WASTE PROGRAM
#
#         Start of Relief   Create_dt of Relief
# 0  21-AUG-2002 00:00:00  24-FEB-2007 14:12:05
# 1                   NaN  22-JAN-2013 09:38:35
# 2  21-AUG-2002 00:00:00  24-FEB-2007 14:12:05
# 3  16-SEP-1988 00:00:00  04-MAR-2011 00:00:00
# 4                   NaN  22-JAN-2013 12:28:00

# %%
# It is also possible to group a DataFrame by multiple columns
# This returns an object with multiple indexes, however, which can be harder to deal with
rlv_df_grpd_st_wt = relevant_df_Water.groupby(['State', 'Supplemental Interest Type'])
rlv_df_grpd_st_wt.count().head(10)
# Out:
#                                        Main Interest Type  Start of Relief  \
# State Supplemental Interest Type
# al    COASTAL ZONE MANAGEMENT (CZM)                   205                0
#       COMMUNITY WATER SYSTEM                          365                0
#       ENFORCEMENT/COMPLIANCE ACTIVITY               48429            23757
#       FORMAL ENFORCEMENT ACTION                      2200             2200
#       HAZARDOUS WASTE PROGRAM                        1551                0
#       INFECTIOUS WASTE                                 23                0
#       LIVESTOCK WASTE CONTROL                         554                0
#       NPDES PERMIT                                   1524                0
#       NPDES STORMWATER PERMIT                        7774                0
#       REFUSE DISPOSAL                                 343                0
#
#                                        Create_dt of Relief
# State Supplemental Interest Type
# al    COASTAL ZONE MANAGEMENT (CZM)                    205
#       COMMUNITY WATER SYSTEM                           365
#       ENFORCEMENT/COMPLIANCE ACTIVITY                48429
#       FORMAL ENFORCEMENT ACTION                       2200
#       HAZARDOUS WASTE PROGRAM                         1551
#       INFECTIOUS WASTE                                  23
#       LIVESTOCK WASTE CONTROL                          554
#       NPDES PERMIT                                    1524
#       NPDES STORMWATER PERMIT                         7774
#       REFUSE DISPOSAL                                  343

# %%
#Dates

start_year = [None if pd.isnull(d) else datetime.datetime.strptime(str(d), "%d-%b-%Y 00:00:00").year  for d in relevant_df_Water["Start of Relief"]]
start_year
# Out:
# [2002,
#  None,
#  2002,
#  1988,
#  None,
#  None,
#  2014,
#  2014,
#  None,
#  None,
#  2013,
#  2010,
#  2004,
#  1992,
#  1996,
#  2002,
#  2004,
#  2002,
#  1996,
#  2003,
#  2003,
#  1993,
#  2002,
#  None,
#  None,
#  None,
#  1979,
#  None,
#  None,
#  None,
#  None,
#  None,
#  2010,
#  2011,
#  2008,
#  2011,
#  1997,
#  None,
#  None,
#  2010,
#  2010,
#  None,
#  None,
#  1977,
#  2005,
#  None,
#  None,
#  None,
#  1994,
#  1995,
#  None,
#  None,
#  2010,
#  None,
#  1996,
#  1996,
#  None,
#  1993,
#  2006,
#  2004,
#  2006,
#  None,
#  None,
#  1996,
#  1996,
#  2019,
#  2013,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1994,
#  1994,
#  1978,
#  None,
#  2012,
#  2003,
#  None,
#  2012,
#  1993,
#  1993,
#  None,
#  None,
#  None,
#  None,
#  2002,
#  None,
#  None,
#  None,
#  None,
#  2000,
#  1997,
#  1997,
#  1977,
#  1977,
#  2003,
#  2003,
#  1983,
#  1983,
#  2000,
#  1994,
#  1993,
#  1993,
#  None,
#  2003,
#  2003,
#  None,
#  None,
#  2004,
#  2004,
#  2000,
#  None,
#  2013,
#  2003,
#  None,
#  2013,
#  None,
#  None,
#  1997,
#  None,
#  None,
#  1999,
#  1999,
#  1999,
#  1996,
#  None,
#  None,
#  2016,
#  None,
#  2016,
#  1977,
#  None,
#  2015,
#  1993,
#  None,
#  None,
#  2010,
#  1993,
#  None,
#  None,
#  1998,
#  1998,
#  1977,
#  None,
#  None,
#  None,
#  None,
#  2001,
#  2001,
#  None,
#  None,
#  2005,
#  None,
#  2009,
#  2005,
#  None,
#  None,
#  2009,
#  None,
#  2000,
#  None,
#  None,
#  None,
#  2014,
#  None,
#  1978,
#  None,
#  None,
#  None,
#  None,
#  2000,
#  2015,
#  1998,
#  None,
#  None,
#  2000,
#  None,
#  2005,
#  2005,
#  2016,
#  1986,
#  1986,
#  1991,
#  1991,
#  2016,
#  1981,
#  1981,
#  2010,
#  2010,
#  2008,
#  2008,
#  2012,
#  2010,
#  2009,
#  2016,
#  2013,
#  2008,
#  2003,
#  None,
#  None,
#  2013,
#  2003,
#  2008,
#  2011,
#  1987,
#  2007,
#  2007,
#  None,
#  None,
#  2004,
#  2004,
#  2007,
#  2011,
#  2007,
#  None,
#  None,
#  None,
#  2002,
#  2002,
#  1986,
#  2003,
#  2011,
#  1982,
#  1977,
#  1986,
#  2011,
#  1994,
#  1994,
#  None,
#  None,
#  None,
#  2009,
#  2009,
#  1997,
#  None,
#  None,
#  None,
#  2003,
#  2003,
#  None,
#  None,
#  1994,
#  1994,
#  2000,
#  None,
#  None,
#  2000,
#  2016,
#  2007,
#  2014,
#  2014,
#  2004,
#  1997,
#  None,
#  2004,
#  None,
#  2005,
#  1994,
#  None,
#  None,
#  2010,
#  2010,
#  None,
#  None,
#  2009,
#  2004,
#  2004,
#  2009,
#  None,
#  1986,
#  2015,
#  1998,
#  None,
#  2006,
#  2006,
#  None,
#  1998,
#  1998,
#  1995,
#  1998,
#  1998,
#  None,
#  None,
#  None,
#  2007,
#  None,
#  None,
#  None,
#  None,
#  2018,
#  2018,
#  2004,
#  2003,
#  2014,
#  2006,
#  2008,
#  2006,
#  2007,
#  1977,
#  None,
#  1998,
#  1998,
#  2004,
#  2004,
#  2004,
#  2004,
#  2004,
#  2013,
#  2013,
#  1994,
#  None,
#  None,
#  1994,
#  None,
#  2017,
#  2000,
#  2010,
#  2000,
#  2010,
#  1977,
#  1976,
#  1976,
#  None,
#  1977,
#  None,
#  2003,
#  2003,
#  1996,
#  None,
#  1998,
#  1998,
#  None,
#  None,
#  2007,
#  2007,
#  1994,
#  1994,
#  2006,
#  None,
#  2011,
#  2013,
#  2009,
#  2009,
#  1998,
#  1998,
#  2013,
#  2007,
#  None,
#  2009,
#  2010,
#  2004,
#  2004,
#  None,
#  2011,
#  None,
#  2013,
#  None,
#  None,
#  2005,
#  1997,
#  1994,
#  2003,
#  2015,
#  None,
#  2006,
#  1984,
#  None,
#  None,
#  None,
#  1978,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1999,
#  None,
#  2001,
#  2001,
#  1999,
#  None,
#  None,
#  2014,
#  2014,
#  None,
#  1997,
#  2014,
#  2014,
#  2014,
#  2014,
#  None,
#  None,
#  2006,
#  None,
#  None,
#  2015,
#  2015,
#  2012,
#  2012,
#  1991,
#  1989,
#  None,
#  None,
#  2005,
#  2011,
#  2011,
#  None,
#  None,
#  2014,
#  1977,
#  None,
#  2010,
#  None,
#  None,
#  None,
#  None,
#  1992,
#  1992,
#  2003,
#  2003,
#  2003,
#  2010,
#  None,
#  None,
#  None,
#  None,
#  2009,
#  None,
#  2004,
#  2009,
#  2009,
#  None,
#  None,
#  None,
#  2011,
#  2011,
#  None,
#  None,
#  None,
#  None,
#  2012,
#  None,
#  2000,
#  None,
#  None,
#  2012,
#  None,
#  1994,
#  None,
#  None,
#  None,
#  2007,
#  2007,
#  2015,
#  None,
#  None,
#  None,
#  2015,
#  2015,
#  2000,
#  2000,
#  1988,
#  2010,
#  2015,
#  None,
#  2008,
#  2014,
#  2000,
#  2000,
#  2004,
#  2004,
#  2014,
#  None,
#  None,
#  1993,
#  1993,
#  None,
#  None,
#  1995,
#  1998,
#  1998,
#  1994,
#  2004,
#  1994,
#  None,
#  None,
#  1994,
#  None,
#  1995,
#  None,
#  None,
#  1995,
#  None,
#  None,
#  2007,
#  2007,
#  1977,
#  2005,
#  2005,
#  None,
#  1994,
#  2005,
#  2005,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1986,
#  None,
#  2013,
#  2013,
#  None,
#  None,
#  1996,
#  None,
#  2006,
#  2006,
#  1985,
#  2017,
#  2006,
#  2010,
#  2010,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1999,
#  1989,
#  2006,
#  None,
#  1977,
#  1977,
#  None,
#  2011,
#  None,
#  2003,
#  2003,
#  1999,
#  1999,
#  None,
#  2011,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1978,
#  None,
#  1995,
#  1995,
#  2003,
#  2003,
#  2010,
#  2010,
#  1993,
#  None,
#  1993,
#  2012,
#  None,
#  None,
#  1999,
#  2012,
#  None,
#  2000,
#  1990,
#  2017,
#  1995,
#  None,
#  None,
#  None,
#  2011,
#  1995,
#  1995,
#  2004,
#  None,
#  2008,
#  2004,
#  2006,
#  None,
#  2014,
#  2014,
#  2006,
#  1998,
#  None,
#  None,
#  None,
#  1999,
#  2011,
#  2011,
#  1999,
#  2017,
#  2003,
#  2003,
#  None,
#  None,
#  2013,
#  None,
#  2017,
#  2017,
#  None,
#  None,
#  2012,
#  2006,
#  None,
#  2003,
#  1995,
#  None,
#  2010,
#  None,
#  2007,
#  2007,
#  None,
#  2009,
#  2009,
#  1977,
#  None,
#  1996,
#  2018,
#  1996,
#  1998,
#  None,
#  None,
#  None,
#  None,
#  2011,
#  None,
#  None,
#  1977,
#  2006,
#  None,
#  None,
#  None,
#  None,
#  None,
#  2014,
#  1999,
#  1999,
#  2010,
#  None,
#  None,
#  1988,
#  None,
#  None,
#  None,
#  None,
#  1988,
#  2006,
#  2006,
#  None,
#  1994,
#  1994,
#  None,
#  None,
#  2015,
#  None,
#  1995,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1998,
#  1998,
#  None,
#  None,
#  1994,
#  None,
#  1994,
#  None,
#  2008,
#  2008,
#  None,
#  None,
#  2015,
#  2015,
#  2015,
#  1999,
#  None,
#  1994,
#  1994,
#  None,
#  2015,
#  1999,
#  1993,
#  2015,
#  2015,
#  None,
#  2011,
#  2016,
#  2011,
#  None,
#  2016,
#  None,
#  2004,
#  2016,
#  2010,
#  2005,
#  2004,
#  None,
#  None,
#  2004,
#  2005,
#  2005,
#  2016,
#  2016,
#  None,
#  None,
#  None,
#  2016,
#  2016,
#  2015,
#  2015,
#  1999,
#  1999,
#  None,
#  None,
#  1998,
#  2014,
#  2014,
#  2007,
#  1993,
#  1993,
#  None,
#  1998,
#  None,
#  1998,
#  2003,
#  2003,
#  2000,
#  2000,
#  None,
#  2003,
#  2003,
#  2006,
#  1993,
#  2006,
#  None,
#  None,
#  2013,
#  2003,
#  2003,
#  None,
#  None,
#  2014,
#  2007,
#  2007,
#  1993,
#  1993,
#  None,
#  None,
#  None,
#  2009,
#  1997,
#  1997,
#  None,
#  None,
#  1999,
#  1999,
#  None,
#  None,
#  1994,
#  2004,
#  2011,
#  2002,
#  2002,
#  2011,
#  2002,
#  2007,
#  2007,
#  1994,
#  1994,
#  None,
#  None,
#  None,
#  None,
#  1993,
#  None,
#  1993,
#  None,
#  1998,
#  1998,
#  2010,
#  2010,
#  None,
#  None,
#  1992,
#  1993,
#  1993,
#  None,
#  None,
#  None,
#  None,
#  2004,
#  2004,
#  None,
#  2015,
#  2009,
#  2009,
#  2000,
#  2001,
#  None,
#  2001,
#  2001,
#  2001,
#  2000,
#  2012,
#  None,
#  2001,
#  2000,
#  2003,
#  1977,
#  2012,
#  2010,
#  2002,
#  2001,
#  None,
#  2006,
#  2006,
#  2019,
#  None,
#  None,
#  None,
#  None,
#  1985,
#  2012,
#  2005,
#  2005,
#  1993,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  2005,
#  2005,
#  None,
#  None,
#  None,
#  None,
#  2005,
#  2006,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1979,
#  1977,
#  2014,
#  2014,
#  1999,
#  None,
#  2017,
#  None,
#  2001,
#  None,
#  None,
#  2015,
#  2015,
#  2015,
#  None,
#  None,
#  2013,
#  1995,
#  1995,
#  None,
#  None,
#  None,
#  None,
#  2016,
#  2016,
#  None,
#  2011,
#  1996,
#  None,
#  None,
#  None,
#  1996,
#  2012,
#  None,
#  None,
#  2010,
#  2010,
#  2013,
#  None,
#  None,
#  2013,
#  1994,
#  None,
#  1993,
#  2013,
#  2007,
#  1995,
#  None,
#  2003,
#  None,
#  None,
#  2013,
#  None,
#  None,
#  None,
#  None,
#  None,
#  2011,
#  2011,
#  2010,
#  None,
#  None,
#  None,
#  None,
#  1993,
#  2010,
#  None,
#  None,
#  2011,
#  None,
#  2011,
#  None,
#  2000,
#  2000,
#  2014,
#  2007,
#  None,
#  2004,
#  2004,
#  2017,
#  1990,
#  2011,
#  None,
#  2009,
#  2001,
#  2001,
#  2012,
#  None,
#  2011,
#  1977,
#  2009,
#  2009,
#  2004,
#  2004,
#  None,
#  None,
#  None,
#  1993,
#  2003,
#  2009,
#  1978,
#  1978,
#  1978,
#  2003,
#  2013,
#  2018,
#  2015,
#  2004,
#  2013,
#  None,
#  None,
#  2005,
#  None,
#  2001,
#  1979,
#  None,
#  None,
#  None,
#  None,
#  1986,
#  None,
#  None,
#  1990,
#  1999,
#  1986,
#  None,
#  None,
#  1999,
#  None,
#  None,
#  1981,
#  2004,
#  2017,
#  None,
#  2006,
#  None,
#  None,
#  None,
#  2006,
#  1978,
#  2005,
#  2010,
#  1982,
#  None,
#  None,
#  ...]

# %%
relevant_df2 = pd.DataFrame({"State":relevant_df_Water["State"],
                           "Main Interest Type":relevant_df_Water["Main Interest Type"], 
                           "Supplemental Interest Type":relevant_df_Water["Supplemental Interest Type"],
                           "Start of Relief":start_year,
                           "Create_dt of Relief":relevant_df_Water["Create_dt of Relief"]})
relevant_df2
# Out:
#       State               Main Interest Type       Supplemental Interest Type  \
# 0        al  ENFORCEMENT/COMPLIANCE ACTIVITY        FORMAL ENFORCEMENT ACTION
# 1        al                     STATE MASTER          NPDES STORMWATER PERMIT
# 2        al        FORMAL ENFORCEMENT ACTION        FORMAL ENFORCEMENT ACTION
# 3        al             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 4        al                     STATE MASTER          HAZARDOUS WASTE PROGRAM
# ...     ...                              ...                              ...
# 15063    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15064    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15065    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15066    va             ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15067    va        FORMAL ENFORCEMENT ACTION        FORMAL ENFORCEMENT ACTION
#
#        Start of Relief   Create_dt of Relief
# 0               2002.0  24-FEB-2007 14:12:05
# 1                  NaN  22-JAN-2013 09:38:35
# 2               2002.0  24-FEB-2007 14:12:05
# 3               1988.0  04-MAR-2011 00:00:00
# 4                  NaN  22-JAN-2013 12:28:00
# ...                ...                   ...
# 15063              NaN  11-SEP-2019 06:28:44
# 15064              NaN  11-SEP-2019 06:28:46
# 15065              NaN  11-SEP-2019 06:28:19
# 15066              NaN  11-SEP-2019 06:28:19
# 15067           2019.0  06-JAN-2020 10:49:53
#
# [1479824 rows x 5 columns]

# %%
#Filter out only the years 2014 - 2018
relevant_yrs = relevant_df2.loc[relevant_df2['Start of Relief'].astype(str).str.contains('2014|2015|2016|2017|2018')]
relevant_yrs
# Out:
#       State      Main Interest Type       Supplemental Interest Type  \
# 6        al    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 7        al  STORM WATER INDUSTRIAL  ENFORCEMENT/COMPLIANCE ACTIVITY
# 135      al  STORM WATER INDUSTRIAL  ENFORCEMENT/COMPLIANCE ACTIVITY
# 138      al    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 141      al            TRI REPORTER  ENFORCEMENT/COMPLIANCE ACTIVITY
# ...     ...                     ...                              ...
# 15004    va    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15014    va    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15025    va    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15044    va    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
# 15049    va    ICIS-NPDES NON-MAJOR  ENFORCEMENT/COMPLIANCE ACTIVITY
#
#        Start of Relief   Create_dt of Relief
# 6               2014.0  05-JUN-2018 00:00:00
# 7               2014.0  05-JUN-2018 00:00:00
# 135             2016.0  04-OCT-2017 00:00:00
# 138             2016.0  04-OCT-2017 00:00:00
# 141             2015.0  01-SEP-2017 13:52:55
# ...                ...                   ...
# 15004           2017.0  11-SEP-2019 06:28:45
# 15014           2017.0  11-SEP-2019 06:28:45
# 15025           2018.0  11-SEP-2019 06:28:19
# 15044           2016.0  11-SEP-2019 06:28:42
# 15049           2017.0  11-SEP-2019 06:28:42
#
# [87457 rows x 5 columns]

# %%
export_state_data = relevant_yrs.to_csv('output_data/e_coast_laws_by_state.csv')

# %%
post_st_cnt = relevant_df2["State"].value_counts()
post_st_cnt
# Out:
# nj    548725
# ny    263849
# ga    151265
# ms     93687
# sc     66302
# nc     63523
# al     62968
# ma     54138
# la     44769
# md     32561
# ri     25235
# de     24616
# ct     22945
# me      9662
# va      8992
# nh      6587
# Name: State, dtype: int64
